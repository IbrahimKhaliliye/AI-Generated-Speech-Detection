# %%
### jupyter notebook file trying to take a look at the data from kaggle one time fake one time real to find trends visually on my own to make the model better
import pandas as pd
import os
import librosa
import librosa.display
import matplotlib.pyplot as plt
from sklearn.preprocessing import normalize
import warnings

import numpy as np
import pickle
import joblib
from sklearn.model_selection import train_test_split
from tensorflow.keras import models, layers
import tensorflow as tf

# %%
dataset = r"C:\Users\alisa\Downloads\DATASET-balanced.csv"


data = pd.read_csv(dataset)

data.head()
# Out:
#    chroma_stft       rms  spectral_centroid  spectral_bandwidth      rolloff  \
# 0     0.338055  0.027948        2842.948867         4322.916759  6570.586186
# 1     0.443766  0.037838        2336.129597         3445.777044  3764.949874
# 2     0.302528  0.056578        2692.988386         2861.133180  4716.610271
# 3     0.319933  0.031504        2241.665382         3503.766175  3798.641521
# 4     0.420055  0.016158        2526.069123         3102.659519  5025.077899
#
#    zero_crossing_rate       mfcc1       mfcc2      mfcc3      mfcc4  ...  \
# 0            0.041050 -462.169586   90.311272  19.073769  24.046888  ...
# 1            0.047730 -409.413422  120.348808  -7.161531   5.114784  ...
# 2            0.080342 -318.996033  120.490273 -24.625771  23.891073  ...
# 3            0.047180 -404.636749  136.320908   2.308172  -3.907071  ...
# 4            0.051905 -410.497925  152.731400 -18.266771  51.993462  ...
#
# ...

# %%
data3=[]
data2 = []
i=0

while True:
    i+=1
    
    if data['LABEL'][i]=='FAKE':
            
            row_data = data.iloc[i].tolist()
            data2.append(row_data)
            
      
    if data['LABEL'][(i)]=='REAL':
            
            row_data = data.iloc[(i)].tolist()
            data3.append(row_data)
            
    if i==11000:
        break

for i in range(30):
      print(data2[i])
      print()
      print(data3[i])
      print()
# Out:
# [0.443766, 0.037838, 2336.129597, 3445.777044, 3764.949874, 0.04773, -409.413422, 120.348808, -7.161531, 5.114784, 8.610174, 12.799644, -5.787597, 0.616004, -2.976074, -5.181348, 0.372541, -2.131157, -6.876417, -1.359395, 0.326401, -5.420016, -2.109968, -1.757634, -9.537907, -8.494421, 'FAKE']
#
# [0.477704, 0.014462, 3016.778974, 3604.604331, 5547.475896, 0.073273, -405.487885, 139.729904, -20.206697, 23.558033, -13.449001, 17.192068, -16.072996, -7.903679, -19.970797, -6.37984, -13.067329, -3.273046, -1.378102, -4.126157, -4.048576, -6.344575, 0.406621, -3.905834, 0.207456, -12.308215, 'REAL']
#
# [0.302528, 0.056578, 2692.988386, 2861.13318, 4716.610271, 0.080342, -318.996033, 120.490273, -24.625771, 23.891073, -9.747897, -3.531111, -11.336594, -6.498098, -5.284181, -6.848886, -3.099179, -5.853725, -3.724773, -6.627182, -5.117002, -6.072106, -0.994653, -1.61712, -3.922354, -7.033001, 'FAKE']
#
# ...
